# %%
from pymongo import MongoClient
from pyspark import SparkContext
from pyspark.sql import SparkSession
import pyspark.sql.functions as F

# %%
spark = SparkSession \
    .builder \
    .appName("myApp") \
    .config("spark.mongodb.input.uri", "mongodb://127.0.0.1/bigdata.raw") \
    .config("spark.mongodb.output.uri", "mongodb://127.0.0.1/bigdata.pairWise") \
    .config('spark.jars.packages', 'org.mongodb.spark:mongo-spark-connector_2.11:2.3.1')\
    .getOrCreate()

# %%
df = spark.read.format("com.mongodb.spark.sql.DefaultSource").load()

# %%
df = df.select("emoji", "sentence")

# %%
def divide_emoji(x):
    return x.split(" ")

def formed_(x):
    result = []
    for emoji in x[0]:
        result.append([emoji, x[1]])
    return result

def separate_emoji(x):
    temp = x.split(',')
    return temp[0]

def separate_position(x):
    temp = x.split(',')
    return temp[1]

# %%
rdd = df.rdd.map(list)
rdd = rdd.map(lambda x: (divide_emoji(x[0]), x[1]))
rdd = rdd.flatMap(lambda x: formed_(x))
rdd = rdd.map(lambda x: (separate_emoji(x[0]), int(separate_position(x[0])), x[1]))
rdd.take(5)
# Out:
# [(':red_heart:',
#   18,
#   'No object is so beautiful that under certain conditions it will not look ugly Oscar Wilde ↺ RT :red_heart: …'),
#  (':person_shrugging:',
#   13,
#   'Cant expect different results doing the same thingdoing stuff different from now on :person_shrugging: 🏻 \u200d :female_sign: ️'),
#  (':female_sign:',
#   15,
#   'Cant expect different results doing the same thingdoing stuff different from now on :person_shrugging: 🏻 \u200d :female_sign: ️'),
#  (':face_with_tears_of_joy:',
#   14,
#   '“ Lets go Marcus ” “ Shiiit where we goin Home ” Marcus Peters :face_with_tears_of_joy:'),
#  (':face_with_tears_of_joy:',
#   14,
#   'Asahd really is a grown man in the body of a 1 year old :face_with_tears_of_joy:')]

# %%
def get_pair(x):
    pos = x[1]
    sentence = x[2]
    words = sentence.split(' ')
    word =''.join(ch for ch in words[pos-1] if ch.isalpha())
    word = word.lower()
    pair = (word, words[pos])
    return pair

def pair_frequency(x):
    pair_freq = {}
    emoji = x[0]
    pairs = x[1]
    for ele in pairs:
        if ele[1] != emoji or ele[0]=='':
            continue
        if ele in pair_freq:
            pair_freq[ele] += 1
        else:
            pair_freq[ele] = 1
    result = list(pair_freq.items())
    result.sort(key = lambda x: x[1], reverse=True)
    return result

# %%
pairs = rdd.map(lambda x: (x[0], get_pair(x)))
group_pairs = pairs.groupBy(lambda x: x[0])
group_pairs = group_pairs.map(lambda x: (x[0], list(x[1])))
temp = group_pairs.map(lambda x: (x[0], [row[1] for row in x[1]]))
result_2 = temp.map(lambda x: (x[0], pair_frequency(x)))
result_2 = result_2.filter(lambda x: len(x[1]) != 0)
result_2 = result_2.sortBy(lambda x: len(x[1]), ascending = False)
result_2.take(2)
# Out:
# [(':face_with_tears_of_joy:',
#   [(('this', ':face_with_tears_of_joy:'), 7063),
#    (('me', ':face_with_tears_of_joy:'), 5371),
#    (('it', ':face_with_tears_of_joy:'), 4971),
#    (('you', ':face_with_tears_of_joy:'), 3329),
#    (('up', ':face_with_tears_of_joy:'), 2401),
#    (('now', ':face_with_tears_of_joy:'), 2346),
#    (('shit', ':face_with_tears_of_joy:'), 2314),
#    (('today', ':face_with_tears_of_joy:'), 2074),
#    (('lol', ':face_with_tears_of_joy:'), 1966),
#    (('that', ':face_with_tears_of_joy:'), 1954),
#    (('day', ':face_with_tears_of_joy:'), 1922),
#    (('time', ':face_with_tears_of_joy:'), 1798),
#    (('out', ':face_with_tears_of_joy:'), 1634),
#    (('him', ':face_with_tears_of_joy:'), 1505),
#    (('too', ':face_with_tears_of_joy:'), 1498),
#    (('again', ':face_with_tears_of_joy:'), 1488),
#    (('lmao', ':face_with_tears_of_joy:'), 1451),
#    (('crying', ':face_with_tears_of_joy:'), 1450),
#    (('funny', ':face_with_tears_of_joy:'), 1410),
#    (('video', ':face_with_tears_of_joy:'), 1373),
#    (('on', ':face_with_tears_of_joy:'), 1220),
#    (('one', ':face_with_tears_of_joy:'), 1177),
#    (('ever', ':face_with_tears_of_joy:'), 1166),
#    (('laughing', ':face_with_tears_of_joy:'), 1128),
#    (('life', ':face_with_tears_of_joy:'), 1100),
#    (('here', ':face_with_tears_of_joy:'), 1096),
#    (('hilarious', ':face_with_tears_of_joy:'), 1094),
#    (('ass', ':face_with_tears_of_joy:'), 1044),
#    (('like', ':face_with_tears_of_joy:'), 1038),
#    (('them', ':face_with_tears_of_joy:'), 992),
#    (('tho', ':face_with_tears_of_joy:'), 962),
#    (('man', ':face_with_tears_of_joy:'), 956),
#    (('her', ':face_with_tears_of_joy:'), 946),
#    (('dead', ':face_with_tears_of_joy:'), 919),
#    (('off', ':face_with_tears_of_joy:'), 892),
#    (('night', ':face_with_tears_of_joy:'), 853),
#    (('is', ':face_with_tears_of_joy:'), 827),
#    (('much', ':face_with_tears_of_joy:'), 800),
#    (('do', ':face_with_tears_of_joy:'), 799),
#    (('back', ':face_with_tears_of_joy:'), 787),
#    (('af', ':face_with_tears_of_joy:'), 732),
#    (('bitch', ':face_with_tears_of_joy:'), 708),
#    (('there', ':face_with_tears_of_joy:'), 696),
#    (('dying', ':face_with_tears_of_joy:'), 659),
#    (('know', ':face_with_tears_of_joy:'), 656),
#    (('though', ':face_with_tears_of_joy:'), 621),
#    (('hell', ':face_with_tears_of_joy:'), 620),
#    (('laugh', ':face_with_tears_of_joy:'), 613),
#    (('thing', ':face_with_tears_of_joy:'), 613),
#    (('us', ':face_with_tears_of_joy:'), 606),
#    (('twitter', ':face_with_tears_of_joy:'), 597),
#    (('all', ':face_with_tears_of_joy:'), 586),
#    (('game', ':face_with_tears_of_joy:'), 584),
#    (('right', ':face_with_tears_of_joy:'), 580),
#    (('friends', ':face_with_tears_of_joy:'), 568),
#    (('nigga', ':face_with_tears_of_joy:'), 563),
#    (('year', ':face_with_tears_of_joy:'), 559),
#    (('bro', ':face_with_tears_of_joy:'), 556),
#    (('response', ':face_with_tears_of_joy:'), 556),
#    (('omg', ':face_with_tears_of_joy:'), 550),
#    (('yall', ':face_with_tears_of_joy:'), 544),
#    (('to', ':face_with_tears_of_joy:'), 540),
#    (('people', ':face_with_tears_of_joy:'), 539),
#    (('good', ':face_with_tears_of_joy:'), 533),
#    (('cute', ':face_with_tears_of_joy:'), 528),
#    (('wrong', ':face_with_tears_of_joy:'), 525),
#    (('car', ':face_with_tears_of_joy:'), 512),
#    (('go', ':face_with_tears_of_joy:'), 509),
#    (('name', ':face_with_tears_of_joy:'), 505),
#    (('hard', ':face_with_tears_of_joy:'), 485),
#    (('face', ':face_with_tears_of_joy:'), 484),
#    (('hoe', ':face_with_tears_of_joy:'), 484),
#    (('weak', ':face_with_tears_of_joy:'), 482),
#    (('else', ':face_with_tears_of_joy:'), 482),
#    (('rn', ':face_with_tears_of_joy:'), 479),
#    (('then', ':face_with_tears_of_joy:'), 470),
#    (('weeks', ':face_with_tears_of_joy:'), 465),
#    (('lmaooo', ':face_with_tears_of_joy:'), 462),
#    (('end', ':face_with_tears_of_joy:'), 462),
#    (('week', ':face_with_tears_of_joy:'), 457),
#    (('in', ':face_with_tears_of_joy:'), 457),
#    (('song', ':face_with_tears_of_joy:'), 456),
#    (('girl', ':face_with_tears_of_joy:'), 452),
#    (('for', ':face_with_tears_of_joy:'), 443),
#    (('seen', ':face_with_tears_of_joy:'), 442),
#    (('work', ':face_with_tears_of_joy:'), 441),
#    (('tweet', ':face_with_tears_of_joy:'), 438),
#    (('down', ':face_with_tears_of_joy:'), 424),
#    (('real', ':face_with_tears_of_joy:'), 420),
#    (('luck', ':face_with_tears_of_joy:'), 411),
#    (('away', ':face_with_tears_of_joy:'), 411),
#    (('well', ':face_with_tears_of_joy:'), 410),
#    (('asf', ':face_with_tears_of_joy:'), 410),
#    (('pic', ':face_with_tears_of_joy:'), 406),
#    (('history', ':face_with_tears_of_joy:'), 394),
#    (('over', ':face_with_tears_of_joy:'), 394),
#    (('together', ':face_with_tears_of_joy:'), 393),
#    (('with', ':face_with_tears_of_joy:'), 371),
#    (('wtf', ':face_with_tears_of_joy:'), 368),
#    (('fool', ':face_with_tears_of_joy:'), 367),
#    (('head', ':face_with_tears_of_joy:'), 367),
#    (('old', ':face_with_tears_of_joy:'), 363),
#    (('mad', ':face_with_tears_of_joy:'), 357),
#    (('movie', ':face_with_tears_of_joy:'), 356),
#    (('phone', ':face_with_tears_of_joy:'), 355),
#    (('bruh', ':face_with_tears_of_joy:'), 351),
#    (('everything', ':face_with_tears_of_joy:'), 351),
#    (('morning', ':face_with_tears_of_joy:'), 346),
#    (('weaaakkk', ':face_with_tears_of_joy:'), 346),
#    (('way', ':face_with_tears_of_joy:'), 344),
#    (('crazy', ':face_with_tears_of_joy:'), 339),
#    (('and', ':face_with_tears_of_joy:'), 336),
#    (('far', ':face_with_tears_of_joy:'), 333),
#    (('please', ':face_with_tears_of_joy:'), 331),
#    (('better', ':face_with_tears_of_joy:'), 330),
#    (('kids', ':face_with_tears_of_joy:'), 329),
#    (('yet', ':face_with_tears_of_joy:'), 323),
#    (('guy', ':face_with_tears_of_joy:'), 321),
#    (('money', ':face_with_tears_of_joy:'), 319),
#    (('haha', ':face_with_tears_of_joy:'), 318),
#    (('days', ':face_with_tears_of_joy:'), 318),
#    (('tonight', ':face_with_tears_of_joy:'), 318),
#    (('not', ':face_with_tears_of_joy:'), 317),
#    (('food', ':face_with_tears_of_joy:'), 316),
#    (('world', ':face_with_tears_of_joy:'), 315),
#    (('anymore', ':face_with_tears_of_joy:'), 314),
#    (('before', ':face_with_tears_of_joy:'), 314),
#    (('doing', ':face_with_tears_of_joy:'), 312),
#    (('alone', ':face_with_tears_of_joy:'), 310),
#    (('more', ':face_with_tears_of_joy:'), 307),
#    (('died', ':face_with_tears_of_joy:'), 304),
#    (('about', ':face_with_tears_of_joy:'), 303),
#    (('fr', ':face_with_tears_of_joy:'), 301),
#    (('fuck', ':face_with_tears_of_joy:'), 301),
#    (('boy', ':face_with_tears_of_joy:'), 301),
#    (('done', ':face_with_tears_of_joy:'), 300),
#    (('already', ':face_with_tears_of_joy:'), 300),
#    (('guys', ':face_with_tears_of_joy:'), 299),
#    (('app', ':face_with_tears_of_joy:'), 299),
#    (('did', ':face_with_tears_of_joy:'), 297),
#    (('home', ':face_with_tears_of_joy:'), 297),
#    (('house', ':face_with_tears_of_joy:'), 295),
#    (('said', ':face_with_tears_of_joy:'), 294),
#    (('bad', ':face_with_tears_of_joy:'), 291),
#    (('best', ':face_with_tears_of_joy:'), 285),
#    (('god', ':face_with_tears_of_joy:'), 282),
#    (('years', ':face_with_tears_of_joy:'), 281),
#    (('started', ':face_with_tears_of_joy:'), 281),
#    (('true', ':face_with_tears_of_joy:'), 281),
#    (('school', ':face_with_tears_of_joy:'), 279),
#    (('something', ':face_with_tears_of_joy:'), 278),
#    (('watch', ':face_with_tears_of_joy:'), 278),
#    (('are', ':face_with_tears_of_joy:'), 277),
#    (('instagram', ':face_with_tears_of_joy:'), 276),
#    (('niggas', ':face_with_tears_of_joy:'), 275),
#    (('got', ':face_with_tears_of_joy:'), 273),
#    (('tears', ':face_with_tears_of_joy:'), 270),
#    (('sometimes', ':face_with_tears_of_joy:'), 270),
#    (('u', ':face_with_tears_of_joy:'), 269),
#    (('own', ':face_with_tears_of_joy:'), 269),
#    (('legend', ':face_with_tears_of_joy:'), 266),
#    (('bed', ':face_with_tears_of_joy:'), 266),
#    (('times', ':face_with_tears_of_joy:'), 266),
#    (('say', ':face_with_tears_of_joy:'), 266),
#    (('show', ':face_with_tears_of_joy:'), 264),
#    (('office', ':face_with_tears_of_joy:'), 264),
#    (('cant', ':face_with_tears_of_joy:'), 264),
#    (('myself', ':face_with_tears_of_joy:'), 263),
#    (('what', ':face_with_tears_of_joy:'), 262),
#    (('k', ':face_with_tears_of_joy:'), 262),
#    (('no', ':face_with_tears_of_joy:'), 261),
#    (('tomorrow', ':face_with_tears_of_joy:'), 260),
#    (('point', ':face_with_tears_of_joy:'), 260),
#    (('boyfriend', ':face_with_tears_of_joy:'), 258),
#    (('job', ':face_with_tears_of_joy:'), 256),
#    (('friend', ':face_with_tears_of_joy:'), 256),
#    (('first', ':face_with_tears_of_joy:'), 255),
#    (('while', ':face_with_tears_of_joy:'), 255),
#    (('son', ':face_with_tears_of_joy:'), 254),
#    (('reactions', ':face_with_tears_of_joy:'), 254),
#    (('why', ':face_with_tears_of_joy:'), 253),
#    (('die', ':face_with_tears_of_joy:'), 252),
#    (('going', ':face_with_tears_of_joy:'), 251),
#    (('tv', ':face_with_tears_of_joy:'), 250),
#    (('class', ':face_with_tears_of_joy:'), 248),
#    (('anything', ':face_with_tears_of_joy:'), 243),
#    (('dad', ':face_with_tears_of_joy:'), 240),
#    (('wife', ':face_with_tears_of_joy:'), 240),
#    (('hair', ':face_with_tears_of_joy:'), 239),
#    (('be', ':face_with_tears_of_joy:'), 238),
#    (('internet', ':face_with_tears_of_joy:'), 237),
#    (('am', ':face_with_tears_of_joy:'), 237),
#    (('sleep', ':face_with_tears_of_joy:'), 236),
#    (('person', ':face_with_tears_of_joy:'), 236),
#    (('fun', ':face_with_tears_of_joy:'), 235),
#    (('everyday', ':face_with_tears_of_joy:'), 235),
#    (('throats', ':face_with_tears_of_joy:'), 229),
#    (('win', ':face_with_tears_of_joy:'), 226),
#    (('wet', ':face_with_tears_of_joy:'), 226),
#    (('either', ':face_with_tears_of_joy:'), 224),
#    (('fan', ':face_with_tears_of_joy:'), 222),
#    (('huh', ':face_with_tears_of_joy:'), 221),
#    (('screaming', ':face_with_tears_of_joy:'), 221),
#    (('picture', ':face_with_tears_of_joy:'), 221),
#    (('himself', ':face_with_tears_of_joy:'), 220),
#    (('yo', ':face_with_tears_of_joy:'), 220),
#    (('stage', ':face_with_tears_of_joy:'), 220),
#    (('breathe', ':face_with_tears_of_joy:'), 218),
#    (('great', ':face_with_tears_of_joy:'), 218),
#    (('baby', ':face_with_tears_of_joy:'), 218),
#    (('reaction', ':face_with_tears_of_joy:'), 216),
#    (('hahaha', ':face_with_tears_of_joy:'), 216),
#    (('happened', ':face_with_tears_of_joy:'), 215),
#    (('at', ':face_with_tears_of_joy:'), 214),
#    (('see', ':face_with_tears_of_joy:'), 212),
#    (('happen', ':face_with_tears_of_joy:'), 211),
#    (('tl', ':face_with_tears_of_joy:'), 211),
#    (('place', ':face_with_tears_of_joy:'), 211),
#    (('same', ':face_with_tears_of_joy:'), 210),
#    (('scene', ':face_with_tears_of_joy:'), 210),
#    (('lit', ':face_with_tears_of_joy:'), 208),
#    (('joke', ':face_with_tears_of_joy:'), 208),
#    (('period', ':face_with_tears_of_joy:'), 206),
#    (('he', ':face_with_tears_of_joy:'), 206),
#    (('knowing', ':face_with_tears_of_joy:'), 205),
#    (('hands', ':face_with_tears_of_joy:'), 203),
#    (('party', ':face_with_tears_of_joy:'), 201),
#    (('babysitter', ':face_with_tears_of_joy:'), 201),
#    (('kid', ':face_with_tears_of_joy:'), 199),
#    (('swear', ':face_with_tears_of_joy:'), 199),
#    (('smh', ':face_with_tears_of_joy:'), 198),
#    (('from', ':face_with_tears_of_joy:'), 197),
#    (('amazing', ':face_with_tears_of_joy:'), 196),
#    (('love', ':face_with_tears_of_joy:'), 196),
#    (('months', ':face_with_tears_of_joy:'), 196),
#    (('fans', ':face_with_tears_of_joy:'), 195),
#    (('team', ':face_with_tears_of_joy:'), 195),
#    (('level', ':face_with_tears_of_joy:'), 193),
#    (('extra', ':face_with_tears_of_joy:'), 193),
#    (('hours', ':face_with_tears_of_joy:'), 191),
#    (('ago', ':face_with_tears_of_joy:'), 191),
#    (('wild', ':face_with_tears_of_joy:'), 190),
#    (('birthday', ':face_with_tears_of_joy:'), 188),
#    (('pregnancy', ':face_with_tears_of_joy:'), 188),
#    (('season', ':face_with_tears_of_joy:'), 187),
#    (('moment', ':face_with_tears_of_joy:'), 186),
#    (('lmfao', ':face_with_tears_of_joy:'), 186),
#    (('em', ':face_with_tears_of_joy:'), 186),
#    (('live', ':face_with_tears_of_joy:'), 184),
#    (('room', ':face_with_tears_of_joy:'), 184),
#    (('enjoy', ':face_with_tears_of_joy:'), 184),
#    (('anyways', ':face_with_tears_of_joy:'), 182),
#    (('quick', ':face_with_tears_of_joy:'), 181),
#    (('tbh', ':face_with_tears_of_joy:'), 181),
#    (('fight', ':face_with_tears_of_joy:'), 181),
#    (('idc', ':face_with_tears_of_joy:'), 180),
#    (('dude', ':face_with_tears_of_joy:'), 180),
#    (('mate', ':face_with_tears_of_joy:'), 180),
#    (('sis', ':face_with_tears_of_joy:'), 180),
#    (('minute', ':face_with_tears_of_joy:'), 180),
#    (('boys', ':face_with_tears_of_joy:'), 178),
#    (('play', ':face_with_tears_of_joy:'), 176),
#    (('of', ':face_with_tears_of_joy:'), 174),
#    (('around', ':face_with_tears_of_joy:'), 174),
#    (('black', ':face_with_tears_of_joy:'), 173),
#    (('sjsjsjjsjsjsjsjs', ':face_with_tears_of_joy:'), 172),
#    (('trash', ':face_with_tears_of_joy:'), 172),
#    (('voice', ':face_with_tears_of_joy:'), 171),
#    (('fortnite', ':face_with_tears_of_joy:'), 169),
#    (('yesterday', ':face_with_tears_of_joy:'), 169),
#    (('bored', ':face_with_tears_of_joy:'), 168),
#    (('tweets', ':face_with_tears_of_joy:'), 168),
#    (('homie', ':face_with_tears_of_joy:'), 167),
#    (('dance', ':face_with_tears_of_joy:'), 167),
#    (('soon', ':face_with_tears_of_joy:'), 166),
#    (('sorry', ':face_with_tears_of_joy:'), 166),
#    (('fam', ':face_with_tears_of_joy:'), 165),
#    (('accurate', ':face_with_tears_of_joy:'), 165),
#    (('happy', ':face_with_tears_of_joy:'), 164),
#    (('sense', ':face_with_tears_of_joy:'), 164),
#    (('turned', ':face_with_tears_of_joy:'), 164),
#    (('daughter', ':face_with_tears_of_joy:'), 163),
#    (('forever', ':face_with_tears_of_joy:'), 163),
#    (('music', ':face_with_tears_of_joy:'), 162),
#    (('cover', ':face_with_tears_of_joy:'), 162),
#    (('story', ':face_with_tears_of_joy:'), 162),
#    (('prank', ':face_with_tears_of_joy:'), 162),
#    (('coming', ':face_with_tears_of_joy:'), 161),
#    (('cope', ':face_with_tears_of_joy:'), 161),
#    (('mom', ':face_with_tears_of_joy:'), 161),
#    (('girls', ':face_with_tears_of_joy:'), 160),
#    (('welcome', ':face_with_tears_of_joy:'), 160),
#    (('table', ':face_with_tears_of_joy:'), 159),
#    (('but', ':face_with_tears_of_joy:'), 159),
#    (('the', ':face_with_tears_of_joy:'), 158),
#    (('playing', ':face_with_tears_of_joy:'), 158),
#    (('other', ':face_with_tears_of_joy:'), 157),
#    (('lmfaooo', ':face_with_tears_of_joy:'), 157),
#    (('was', ':face_with_tears_of_joy:'), 157),
#    (('heaven', ':face_with_tears_of_joy:'), 156),
#    (('okay', ':face_with_tears_of_joy:'), 155),
#    (('long', ':face_with_tears_of_joy:'), 155),
#    (('eat', ':face_with_tears_of_joy:'), 154),
#    (('stop', ':face_with_tears_of_joy:'), 152),
#    (('chill', ':face_with_tears_of_joy:'), 152),
#    (('mood', ':face_with_tears_of_joy:'), 151),
#    (('anyway', ':face_with_tears_of_joy:'), 151),
#    (('hit', ':face_with_tears_of_joy:'), 151),
#    (('break', ':face_with_tears_of_joy:'), 151),
#    (('lot', ':face_with_tears_of_joy:'), 150),
#    (('problem', ':face_with_tears_of_joy:'), 149),
#    (('funnier', ':face_with_tears_of_joy:'), 149),
#    (('pictures', ':face_with_tears_of_joy:'), 148),
#    (('yourself', ':face_with_tears_of_joy:'), 148),
#    (('so', ':face_with_tears_of_joy:'), 148),
#    (('everybody', ':face_with_tears_of_joy:'), 147),
#    (('shot', ':face_with_tears_of_joy:'), 147),
#    (('mind', ':face_with_tears_of_joy:'), 146),
#    (('happens', ':face_with_tears_of_joy:'), 146),
#    (('lie', ':face_with_tears_of_joy:'), 146),
#    (('account', ':face_with_tears_of_joy:'), 145),
#    (('instead', ':face_with_tears_of_joy:'), 143),
#    (('reason', ':face_with_tears_of_joy:'), 143),
#    (('serious', ':face_with_tears_of_joy:'), 143),
#    (('body', ':face_with_tears_of_joy:'), 143),
#    (('meme', ':face_with_tears_of_joy:'), 143),
#    (('relate', ':face_with_tears_of_joy:'), 142),
#    (('mean', ':face_with_tears_of_joy:'), 142),
#    (('talk', ':face_with_tears_of_joy:'), 142),
#    (('think', ':face_with_tears_of_joy:'), 142),
#    (('brother', ':face_with_tears_of_joy:'), 141),
#    (('hand', ':face_with_tears_of_joy:'), 141),
#    (('mama', ':face_with_tears_of_joy:'), 141),
#    (('savage', ':face_with_tears_of_joy:'), 141),
#    (('things', ':face_with_tears_of_joy:'), 141),
#    (('energy', ':face_with_tears_of_joy:'), 139),
#    (('mans', ':face_with_tears_of_joy:'), 139),
#    (('heart', ':face_with_tears_of_joy:'), 138),
#    (('babies', ':face_with_tears_of_joy:'), 136),
#    (('care', ':face_with_tears_of_joy:'), 136),
#    (('news', ':face_with_tears_of_joy:'), 136),
#    (('dick', ':face_with_tears_of_joy:'), 136),
#    (('nooo', ':face_with_tears_of_joy:'), 136),
#    (('ok', ':face_with_tears_of_joy:'), 135),
#    (('fine', ':face_with_tears_of_joy:'), 135),
#    (('these', ':face_with_tears_of_joy:'), 134),
#    (('hurt', ':face_with_tears_of_joy:'), 134),
#    (('bucket', ':face_with_tears_of_joy:'), 134),
#    (('club', ':face_with_tears_of_joy:'), 134),
#    (('weekend', ':face_with_tears_of_joy:'), 133),
#    (('lmaoo', ':face_with_tears_of_joy:'), 133),
#    (('coachella', ':face_with_tears_of_joy:'), 133),
#    (('fast', ':face_with_tears_of_joy:'), 132),
#    (('tf', ':face_with_tears_of_joy:'), 132),
#    (('magic', ':face_with_tears_of_joy:'), 131),
#    (('stuff', ':face_with_tears_of_joy:'), 131),
#    (('month', ':face_with_tears_of_joy:'), 131),
#    (('feelings', ':face_with_tears_of_joy:'), 130),
#    (('synced', ':face_with_tears_of_joy:'), 130),
#    (('part', ':face_with_tears_of_joy:'), 130),
#    (('yes', ':face_with_tears_of_joy:'), 130),
#    (('mine', ':face_with_tears_of_joy:'), 129),
#    (('album', ':face_with_tears_of_joy:'), 129),
#    (('dumb', ':face_with_tears_of_joy:'), 129),
#    (('priceless', ':face_with_tears_of_joy:'), 128),
#    (('start', ':face_with_tears_of_joy:'), 127),
#    (('assignment', ':face_with_tears_of_joy:'), 127),
#    (('match', ':face_with_tears_of_joy:'), 127),
#    (('ears', ':face_with_tears_of_joy:'), 127),
#    (('loud', ':face_with_tears_of_joy:'), 126),
#    (('clown', ':face_with_tears_of_joy:'), 126),
#    (('bathroom', ':face_with_tears_of_joy:'), 126),
#    (('want', ':face_with_tears_of_joy:'), 126),
#    (('high', ':face_with_tears_of_joy:'), 126),
#    (('videos', ':face_with_tears_of_joy:'), 125),
#    (('ready', ':face_with_tears_of_joy:'), 125),
#    (('hoes', ':face_with_tears_of_joy:'), 123),
#    (('drunk', ':face_with_tears_of_joy:'), 122),
#    (('mouth', ':face_with_tears_of_joy:'), 122),
#    (('nothing', ':face_with_tears_of_joy:'), 122),
#    (('minutes', ':face_with_tears_of_joy:'), 122),
#    (('everyone', ':face_with_tears_of_joy:'), 122),
#    (('understand', ':face_with_tears_of_joy:'), 121),
#    (('look', ':face_with_tears_of_joy:'), 121),
#    (('help', ':face_with_tears_of_joy:'), 121),
#    (('wait', ':face_with_tears_of_joy:'), 120),
#    (('household', ':face_with_tears_of_joy:'), 120),
#    (('boring', ':face_with_tears_of_joy:'), 120),
#    (('girlfriend', ':face_with_tears_of_joy:'), 119),
#    (('enough', ':face_with_tears_of_joy:'), 119),
#    (('ideas', ':face_with_tears_of_joy:'), 118),
#    (('questions', ':face_with_tears_of_joy:'), 118),
#    (('usher', ':face_with_tears_of_joy:'), 118),
#    (('heavy', ':face_with_tears_of_joy:'), 118),
#    (('characters', ':face_with_tears_of_joy:'), 117),
#    (('rt', ':face_with_tears_of_joy:'), 117),
#    (('jimin', ':face_with_tears_of_joy:'), 116),
#    (('gay', ':face_with_tears_of_joy:'), 116),
#    (('men', ':face_with_tears_of_joy:'), 116),
#    (('gif', ':face_with_tears_of_joy:'), 116),
#    (('business', ':face_with_tears_of_joy:'), 116),
#    (('question', ':face_with_tears_of_joy:'), 116),
#    (('calls', ':face_with_tears_of_joy:'), 115),
#    (('everywhere', ':face_with_tears_of_joy:'), 115),
#    (('version', ':face_with_tears_of_joy:'), 114),
#    (('stupid', ':face_with_tears_of_joy:'), 114),
#    (('by', ':face_with_tears_of_joy:'), 114),
#    (('ugly', ':face_with_tears_of_joy:'), 114),
#    (('canada', ':face_with_tears_of_joy:'), 114),
#    (('weed', ':face_with_tears_of_joy:'), 114),
#    (('president', ':face_with_tears_of_joy:'), 113),
#    (('store', ':face_with_tears_of_joy:'), 113),
#    (('sex', ':face_with_tears_of_joy:'), 113),
#    (('g', ':face_with_tears_of_joy:'), 113),
#    (('momma', ':face_with_tears_of_joy:'), 112),
#    (('gold', ':face_with_tears_of_joy:'), 112),
#    (('yeah', ':face_with_tears_of_joy:'), 112),
#    (('photo', ':face_with_tears_of_joy:'), 111),
#    (('sleepovers', ':face_with_tears_of_joy:'), 111),
#    (('get', ':face_with_tears_of_joy:'), 110),
#    (('lyrics', ':face_with_tears_of_joy:'), 110),
#    (('games', ':face_with_tears_of_joy:'), 110),
#    (('deep', ':face_with_tears_of_joy:'), 109),
#    (('mexico', ':face_with_tears_of_joy:'), 109),
#    (('wow', ':face_with_tears_of_joy:'), 109),
#    (('relationship', ':face_with_tears_of_joy:'), 108),
#    (('sure', ':face_with_tears_of_joy:'), 108),
#    (('senses', ':face_with_tears_of_joy:'), 108),
#    (('lmfaoo', ':face_with_tears_of_joy:'), 107),
#    (('tournament', ':face_with_tears_of_joy:'), 107),
#    (('bitches', ':face_with_tears_of_joy:'), 107),
#    (('city', ':face_with_tears_of_joy:'), 107),
#    (('water', ':face_with_tears_of_joy:'), 106),
#    (('dis', ':face_with_tears_of_joy:'), 105),
#    (('mf', ':face_with_tears_of_joy:'), 105),
#    (('made', ':face_with_tears_of_joy:'), 104),
#    (('pocket', ':face_with_tears_of_joy:'), 104),
#    (('dawg', ':face_with_tears_of_joy:'), 104),
#    (('post', ':face_with_tears_of_joy:'), 103),
#    (('smooth', ':face_with_tears_of_joy:'), 103),
#    (('can', ':face_with_tears_of_joy:'), 103),
#    (('legendary', ':face_with_tears_of_joy:'), 103),
#    (('seriously', ':face_with_tears_of_joy:'), 103),
#    (('line', ':face_with_tears_of_joy:'), 102),
#    (('late', ':face_with_tears_of_joy:'), 102),
#    (('honest', ':face_with_tears_of_joy:'), 102),
#    (('edition', ':face_with_tears_of_joy:'), 102),
#    (('embiid', ':face_with_tears_of_joy:'), 102),
#    (('maps', ':face_with_tears_of_joy:'), 102),
#    (('storm', ':face_with_tears_of_joy:'), 102),
#    (('exam', ':face_with_tears_of_joy:'), 101),
#    (('attention', ':face_with_tears_of_joy:'), 101),
#    (('shower', ':face_with_tears_of_joy:'), 101),
#    (('league', ':face_with_tears_of_joy:'), 101),
#    (('family', ':face_with_tears_of_joy:'), 100),
#    (('earth', ':face_with_tears_of_joy:'), 100),
#    (('followers', ':face_with_tears_of_joy:'), 100),
#    (('born', ':face_with_tears_of_joy:'), 100),
#    (('snap', ':face_with_tears_of_joy:'), 99),
#    (('everytime', ':face_with_tears_of_joy:'), 99),
#    (('forgotten', ':face_with_tears_of_joy:'), 99),
#    (('goals', ':face_with_tears_of_joy:'), 99),
#    (('anyone', ':face_with_tears_of_joy:'), 99),
#    (('cry', ':face_with_tears_of_joy:'), 99),
#    (('child', ':face_with_tears_of_joy:'), 99),
#    (('shootaround', ':face_with_tears_of_joy:'), 98),
#    (('songs', ':face_with_tears_of_joy:'), 98),
#    (('free', ':face_with_tears_of_joy:'), 98),
#    (('mess', ':face_with_tears_of_joy:'), 97),
#    (('jokes', ':face_with_tears_of_joy:'), 97),
#    (('hour', ':face_with_tears_of_joy:'), 97),
#    (('act', ':face_with_tears_of_joy:'), 96),
#    (('photos', ':face_with_tears_of_joy:'), 96),
#    (('bowl', ':face_with_tears_of_joy:'), 96),
#    (('nice', ':face_with_tears_of_joy:'), 95),
#    (('facts', ':face_with_tears_of_joy:'), 95),
#    (('ya', ':face_with_tears_of_joy:'), 95),
#    (('meee', ':face_with_tears_of_joy:'), 95),
#    (('sister', ':face_with_tears_of_joy:'), 95),
#    (('have', ':face_with_tears_of_joy:'), 95),
#    (('media', ':face_with_tears_of_joy:'), 94),
#    (('dog', ':face_with_tears_of_joy:'), 94),
#    (('says', ':face_with_tears_of_joy:'), 94),
#    (('trip', ':face_with_tears_of_joy:'), 93),
#    (('lying', ':face_with_tears_of_joy:'), 93),
#    (('weird', ':face_with_tears_of_joy:'), 93),
#    (('saying', ':face_with_tears_of_joy:'), 92),
#    (('case', ':face_with_tears_of_joy:'), 92),
#    (('classic', ':face_with_tears_of_joy:'), 92),
#    (('hai', ':face_with_tears_of_joy:'), 92),
#    (('cheating', ':face_with_tears_of_joy:'), 92),
#    (('church', ':face_with_tears_of_joy:'), 91),
#    (('pics', ':face_with_tears_of_joy:'), 91),
#    (('episode', ':face_with_tears_of_joy:'), 91),
#    (('sad', ':face_with_tears_of_joy:'), 90),
#    (('a', ':face_with_tears_of_joy:'), 90),
#    (('yours', ':face_with_tears_of_joy:'), 90),
#    (('wedding', ':face_with_tears_of_joy:'), 90),
#    (('truth', ':face_with_tears_of_joy:'), 90),
#    (('comedy', ':face_with_tears_of_joy:'), 90),
#    (('thread', ':face_with_tears_of_joy:'), 89),
#    (('door', ':face_with_tears_of_joy:'), 89),
#    (('reunion', ':face_with_tears_of_joy:'), 89),
#    (('dramatic', ':face_with_tears_of_joy:'), 89),
#    (('both', ':face_with_tears_of_joy:'), 89),
#    (('pls', ':face_with_tears_of_joy:'), 88),
#    (('word', ':face_with_tears_of_joy:'), 88),
#    (('later', ':face_with_tears_of_joy:'), 88),
#    (('idea', ':face_with_tears_of_joy:'), 88),
#    (('s', ':face_with_tears_of_joy:'), 88),
#    (('i', ':face_with_tears_of_joy:'), 88),
#    (('trump', ':face_with_tears_of_joy:'), 87),
#    (('facebook', ':face_with_tears_of_joy:'), 87),
#    (('ffs', ':face_with_tears_of_joy:'), 87),
#    (('married', ':face_with_tears_of_joy:'), 87),
#    (('does', ':face_with_tears_of_joy:'), 87),
#    (('since', ':face_with_tears_of_joy:'), 87),
#    (('burger', ':face_with_tears_of_joy:'), 87),
#    (('na', ':face_with_tears_of_joy:'), 87),
#    (('america', ':face_with_tears_of_joy:'), 87),
#    (('shmurda', ':face_with_tears_of_joy:'), 87),
#    (('undefeated', ':face_with_tears_of_joy:'), 87),
#    (('o', ':face_with_tears_of_joy:'), 87),
#    (('memes', ':face_with_tears_of_joy:'), 86),
#    (('viral', ':face_with_tears_of_joy:'), 86),
#    (('cash', ':face_with_tears_of_joy:'), 86),
#    (('annoying', ':face_with_tears_of_joy:'), 86),
#    (('nowhere', ':face_with_tears_of_joy:'), 86),
#    (('hahahaha', ':face_with_tears_of_joy:'), 85),
#    (('country', ':face_with_tears_of_joy:'), 85),
#    (('left', ':face_with_tears_of_joy:'), 85),
#    (('self', ':face_with_tears_of_joy:'), 85),
#    (('list', ':face_with_tears_of_joy:'), 84),
#    (('clue', ':face_with_tears_of_joy:'), 84),
#    (('stomach', ':face_with_tears_of_joy:'), 84),
#    (('once', ':face_with_tears_of_joy:'), 84),
#    (('damn', ':face_with_tears_of_joy:'), 84),
#    (('chest', ':face_with_tears_of_joy:'), 84),
#    (('concert', ':face_with_tears_of_joy:'), 84),
#    (('dont', ':face_with_tears_of_joy:'), 83),
#    (('cool', ':face_with_tears_of_joy:'), 83),
#    (('floor', ':face_with_tears_of_joy:'), 83),
#    (('broke', ':face_with_tears_of_joy:'), 83),
#    (('really', ':face_with_tears_of_joy:'), 83),
#    (('rollinnn', ':face_with_tears_of_joy:'), 83),
#    (('prodigy', ':face_with_tears_of_joy:'), 83),
#    (('gone', ':face_with_tears_of_joy:'), 82),
#    (('just', ':face_with_tears_of_joy:'), 82),
#    (('gem', ':face_with_tears_of_joy:'), 82),
#    (('moms', ':face_with_tears_of_joy:'), 82),
#    (('early', ':face_with_tears_of_joy:'), 82),
#    (('young', ':face_with_tears_of_joy:'), 82),
#    (('overslept', ':face_with_tears_of_joy:'), 82),
#    (('lost', ':face_with_tears_of_joy:'), 81),
#    (('ig', ':face_with_tears_of_joy:'), 81),
#    (('words', ':face_with_tears_of_joy:'), 81),
#    (('snapchat', ':face_with_tears_of_joy:'), 81),
#    (('smile', ':face_with_tears_of_joy:'), 81),
#    (('brilliant', ':face_with_tears_of_joy:'), 81),
#    (('ex', ':face_with_tears_of_joy:'), 81),
#    (('interview', ':face_with_tears_of_joy:'), 80),
#    (('change', ':face_with_tears_of_joy:'), 80),
#    (('tried', ':face_with_tears_of_joy:'), 80),
#    (('eyes', ':face_with_tears_of_joy:'), 80),
#    (('fake', ':face_with_tears_of_joy:'), 80),
#    (('side', ':face_with_tears_of_joy:'), 80),
#    (('confused', ':face_with_tears_of_joy:'), 79),
#    (('dogs', ':face_with_tears_of_joy:'), 79),
#    (('goal', ':face_with_tears_of_joy:'), 79),
#    (('reply', ':face_with_tears_of_joy:'), 79),
#    (('thought', ':face_with_tears_of_joy:'), 79),
#    (('another', ':face_with_tears_of_joy:'), 79),
#    (('date', ':face_with_tears_of_joy:'), 79),
#    (('tour', ':face_with_tears_of_joy:'), 79),
#    (('difference', ':face_with_tears_of_joy:'), 78),
#    (('iconic', ':face_with_tears_of_joy:'), 78),
#    (('challenge', ':face_with_tears_of_joy:'), 78),
#    (('thanks', ':face_with_tears_of_joy:'), 78),
#    (('shook', ':face_with_tears_of_joy:'), 78),
#    (('doll', ':face_with_tears_of_joy:'), 78),
#    (('meanwhile', ':face_with_tears_of_joy:'), 77),
#    (('ball', ':face_with_tears_of_joy:'), 77),
#    (('fools', ':face_with_tears_of_joy:'), 77),
#    (('answer', ':face_with_tears_of_joy:'), 77),
#    (('genius', ':face_with_tears_of_joy:'), 76),
#    (('culture', ':face_with_tears_of_joy:'), 76),
#    (('army', ':face_with_tears_of_joy:'), 76),
#    (('easy', ':face_with_tears_of_joy:'), 76),
#    (('fired', ':face_with_tears_of_joy:'), 76),
#    (('pussy', ':face_with_tears_of_joy:'), 76),
#    (('read', ':face_with_tears_of_joy:'), 76),
#    (('woman', ':face_with_tears_of_joy:'), 76),
#    (('jail', ':face_with_tears_of_joy:'), 75),
#    (('nobody', ':face_with_tears_of_joy:'), 75),
#    (('ligament', ':face_with_tears_of_joy:'), 75),
#    (('speak', ':face_with_tears_of_joy:'), 75),
#    (('after', ':face_with_tears_of_joy:'), 75),
#    (('tired', ':face_with_tears_of_joy:'), 75),
#    (('id', ':face_with_tears_of_joy:'), 75),
#    (('next', ':face_with_tears_of_joy:'), 74),
#    (('shiii', ':face_with_tears_of_joy:'), 74),
#    (('group', ':face_with_tears_of_joy:'), 74),
#    (('pregnant', ':face_with_tears_of_joy:'), 74),
#    (('two', ':face_with_tears_of_joy:'), 74),
#    (('award', ':face_with_tears_of_joy:'), 73),
#    (('vid', ':face_with_tears_of_joy:'), 73),
#    (('jamaican', ':face_with_tears_of_joy:'), 73),
#    (('cat', ':face_with_tears_of_joy:'), 73),
#    (('deal', ':face_with_tears_of_joy:'), 73),
#    (('seconds', ':face_with_tears_of_joy:'), 72),
#    (('english', ':face_with_tears_of_joy:'), 72),
#    (('bit', ':face_with_tears_of_joy:'), 72),
#    (('nuts', ':face_with_tears_of_joy:'), 72),
#    (('soul', ':face_with_tears_of_joy:'), 72),
#    (('arsenal', ':face_with_tears_of_joy:'), 72),
#    (('earlier', ':face_with_tears_of_joy:'), 72),
#    (('lose', ':face_with_tears_of_joy:'), 72),
#    (('won', ':face_with_tears_of_joy:'), 72),
#    (('number', ':face_with_tears_of_joy:'), 72),
#    (('shoes', ':face_with_tears_of_joy:'), 71),
#    (('bag', ':face_with_tears_of_joy:'), 71),
#    (('walmart', ':face_with_tears_of_joy:'), 71),
#    (('twice', ':face_with_tears_of_joy:'), 71),
#    (('makeup', ':face_with_tears_of_joy:'), 71),
#    (('style', ':face_with_tears_of_joy:'), 70),
#    (('comments', ':face_with_tears_of_joy:'), 70),
#    (('arguing', ':face_with_tears_of_joy:'), 70),
#    (('brown', ':face_with_tears_of_joy:'), 70),
#    (('perfect', ':face_with_tears_of_joy:'), 70),
#    (('ghost', ':face_with_tears_of_joy:'), 70),
#    (('leave', ':face_with_tears_of_joy:'), 70),
#    (('passing', ':face_with_tears_of_joy:'), 69),
#    (('icarly', ':face_with_tears_of_joy:'), 69),
#    (('final', ':face_with_tears_of_joy:'), 69),
#    (('excited', ':face_with_tears_of_joy:'), 69),
#    (('thinking', ':face_with_tears_of_joy:'), 69),
#    (('special', ':face_with_tears_of_joy:'), 68),
#    (('gym', ':face_with_tears_of_joy:'), 68),
#    (('pop', ':face_with_tears_of_joy:'), 68),
#    (('hyung', ':face_with_tears_of_joy:'), 68),
#    (('friday', ':face_with_tears_of_joy:'), 68),
#    (('alive', ':face_with_tears_of_joy:'), 68),
#    (('feel', ':face_with_tears_of_joy:'), 68),
#    (('smoke', ':face_with_tears_of_joy:'), 68),
#    (('chance', ':face_with_tears_of_joy:'), 68),
#    (('card', ':face_with_tears_of_joy:'), 68),
#    (('happening', ':face_with_tears_of_joy:'), 67),
#    (('b', ':face_with_tears_of_joy:'), 67),
#    (('shambles', ':face_with_tears_of_joy:'), 67),
#    (('move', ':face_with_tears_of_joy:'), 67),
#    (('peace', ':face_with_tears_of_joy:'), 67),
#    (('will', ':face_with_tears_of_joy:'), 67),
#    (('someone', ':face_with_tears_of_joy:'), 67),
#    (('feeling', ':face_with_tears_of_joy:'), 67),
#    (('knew', ':face_with_tears_of_joy:'), 67),
#    (('weapon', ':face_with_tears_of_joy:'), 67),
#    (('single', ':face_with_tears_of_joy:'), 67),
#    (('shoot', ':face_with_tears_of_joy:'), 67),
#    (('guess', ':face_with_tears_of_joy:'), 66),
#    (('tuxedo', ':face_with_tears_of_joy:'), 66),
#    (('fandom', ':face_with_tears_of_joy:'), 66),
#    (('chicken', ':face_with_tears_of_joy:'), 66),
#    (('accident', ':face_with_tears_of_joy:'), 66),
#    (('min', ':face_with_tears_of_joy:'), 66),
#    (('set', ':face_with_tears_of_joy:'), 66),
#    (('argue', ':face_with_tears_of_joy:'), 66),
#    (('trouble', ':face_with_tears_of_joy:'), 66),
#    (('africa', ':face_with_tears_of_joy:'), 65),
#    (('monday', ':face_with_tears_of_joy:'), 65),
#    (('issues', ':face_with_tears_of_joy:'), 65),
#    (('shirt', ':face_with_tears_of_joy:'), 65),
#    (('fire', ':face_with_tears_of_joy:'), 65),
#    (('approve', ':face_with_tears_of_joy:'), 65),
#    (('retarded', ':face_with_tears_of_joy:'), 65),
#    (('rat', ':face_with_tears_of_joy:'), 65),
#    (('gun', ':face_with_tears_of_joy:'), 64),
#    (('button', ':face_with_tears_of_joy:'), 64),
#    (('try', ':face_with_tears_of_joy:'), 64),
#    (('bite', ':face_with_tears_of_joy:'), 64),
#    (('nfs', ':face_with_tears_of_joy:'), 63),
#    (('studio', ':face_with_tears_of_joy:'), 63),
#    (('lately', ':face_with_tears_of_joy:'), 63),
#    (('bruhhh', ':face_with_tears_of_joy:'), 63),
#    (('some', ':face_with_tears_of_joy:'), 63),
#    (('daddy', ':face_with_tears_of_joy:'), 63),
#    (('form', ':face_with_tears_of_joy:'), 62),
#    (('beat', ':face_with_tears_of_joy:'), 62),
#    (('dangerous', ':face_with_tears_of_joy:'), 62),
#    (('worse', ':face_with_tears_of_joy:'), 62),
#    (('sunday', ':face_with_tears_of_joy:'), 62),
#    (('run', ':face_with_tears_of_joy:'), 62),
#    (('camera', ':face_with_tears_of_joy:'), 62),
#    (('cold', ':face_with_tears_of_joy:'), 62),
#    (('butt', ':face_with_tears_of_joy:'), 62),
#    (('battle', ':face_with_tears_of_joy:'), 61),
#    (('outside', ':face_with_tears_of_joy:'), 61),
#    (('quickly', ':face_with_tears_of_joy:'), 61),
#    (('moves', ':face_with_tears_of_joy:'), 61),
#    (('x', ':face_with_tears_of_joy:'), 61),
#    (('mother', ':face_with_tears_of_joy:'), 61),
#    (('anime', ':face_with_tears_of_joy:'), 61),
#    (('update', ':face_with_tears_of_joy:'), 61),
#    (('sick', ':face_with_tears_of_joy:'), 61),
#    (('ones', ':face_with_tears_of_joy:'), 61),
#    (('most', ':face_with_tears_of_joy:'), 60),
#    (('eh', ':face_with_tears_of_joy:'), 60),
#    (('awesome', ':face_with_tears_of_joy:'), 60),
#    (('watching', ':face_with_tears_of_joy:'), 60),
#    (('pissed', ':face_with_tears_of_joy:'), 60),
#    (('top', ':face_with_tears_of_joy:'), 60),
#    (('pods', ':face_with_tears_of_joy:'), 60),
#    (('literally', ':face_with_tears_of_joy:'), 60),
#    (('leader', ':face_with_tears_of_joy:'), 60),
#    (('poisoning', ':face_with_tears_of_joy:'), 60),
#    (('trying', ':face_with_tears_of_joy:'), 60),
#    (('winning', ':face_with_tears_of_joy:'), 60),
#    (('fasho', ':face_with_tears_of_joy:'), 59),
#    (('embarrassed', ':face_with_tears_of_joy:'), 59),
#    (('gets', ':face_with_tears_of_joy:'), 59),
#    (('had', ':face_with_tears_of_joy:'), 59),
#    (('jin', ':face_with_tears_of_joy:'), 59),
#    (('laughter', ':face_with_tears_of_joy:'), 59),
#    (('cats', ':face_with_tears_of_joy:'), 59),
#    (('amp', ':face_with_tears_of_joy:'), 59),
#    (('caption', ':face_with_tears_of_joy:'), 59),
#    (('paid', ':face_with_tears_of_joy:'), 59),
#    (('open', ':face_with_tears_of_joy:'), 59),
#    (('plane', ':face_with_tears_of_joy:'), 58),
#    (('drop', ':face_with_tears_of_joy:'), 58),
#    (('only', ':face_with_tears_of_joy:'), 58),
#    (('dirty', ':face_with_tears_of_joy:'), 58),
#    (('advice', ':face_with_tears_of_joy:'), 58),
#    (('l', ':face_with_tears_of_joy:'), 58),
#    (('career', ':face_with_tears_of_joy:'), 58),
#    (('different', ':face_with_tears_of_joy:'), 58),
#    (('risk', ':face_with_tears_of_joy:'), 58),
#    (('football', ':face_with_tears_of_joy:'), 58),
#    (('page', ':face_with_tears_of_joy:'), 58),
#    (('movies', ':face_with_tears_of_joy:'), 58),
#    (('talking', ':face_with_tears_of_joy:'), 57),
#    (('language', ':face_with_tears_of_joy:'), 57),
#    (('possible', ':face_with_tears_of_joy:'), 57),
#    (('where', ':face_with_tears_of_joy:'), 57),
#    (('players', ':face_with_tears_of_joy:'), 57),
#    (('crowd', ':face_with_tears_of_joy:'), 57),
#    (('bullshit', ':face_with_tears_of_joy:'), 57),
#    (('th', ':face_with_tears_of_joy:'), 57),
#    (('dancing', ':face_with_tears_of_joy:'), 57),
#    (('pm', ':face_with_tears_of_joy:'), 57),
#    (('breakfast', ':face_with_tears_of_joy:'), 57),
#    (('come', ':face_with_tears_of_joy:'), 57),
#    (('drink', ':face_with_tears_of_joy:'), 57),
#    (('white', ':face_with_tears_of_joy:'), 57),
#    (('hahahahaha', ':face_with_tears_of_joy:'), 57),
#    (('problems', ':face_with_tears_of_joy:'), 56),
#    (('m', ':face_with_tears_of_joy:'), 56),
#    (('giving', ':face_with_tears_of_joy:'), 56),
#    (('inside', ':face_with_tears_of_joy:'), 56),
#    (('hot', ':face_with_tears_of_joy:'), 56),
#    (('bae', ':face_with_tears_of_joy:'), 56),
#    (('player', ':face_with_tears_of_joy:'), 56),
#    (('bowmasters', ':face_with_tears_of_joy:'), 56),
#    (('omfg', ':face_with_tears_of_joy:'), 56),
#    (('dropping', ':face_with_tears_of_joy:'), 56),
#    (('awards', ':face_with_tears_of_joy:'), 56),
#    (('scared', ':face_with_tears_of_joy:'), 56),
#    (('dinner', ':face_with_tears_of_joy:'), 56),
#    (('anybody', ':face_with_tears_of_joy:'), 56),
#    (('box', ':face_with_tears_of_joy:'), 55),
#    (('comment', ':face_with_tears_of_joy:'), 55),
#    (('parent', ':face_with_tears_of_joy:'), 55),
#    (('honestly', ':face_with_tears_of_joy:'), 55),
#    (('pain', ':face_with_tears_of_joy:'), 55),
#    (('background', ':face_with_tears_of_joy:'), 55),
#    (('present', ':face_with_tears_of_joy:'), 55),
#    (('new', ':face_with_tears_of_joy:'), 54),
#    (('track', ':face_with_tears_of_joy:'), 54),
#    (('height', ':face_with_tears_of_joy:'), 54),
#    (('sir', ':face_with_tears_of_joy:'), 54),
#    (('smart', ':face_with_tears_of_joy:'), 54),
#    (('unpacking', ':face_with_tears_of_joy:'), 54),
#    (('age', ':face_with_tears_of_joy:'), 54),
#    (('performance', ':face_with_tears_of_joy:'), 54),
#    (('rest', ':face_with_tears_of_joy:'), 54),
#    (('buddy', ':face_with_tears_of_joy:'), 54),
#    (('whaaat', ':face_with_tears_of_joy:'), 54),
#    (('cake', ':face_with_tears_of_joy:'), 54),
#    (('course', ':face_with_tears_of_joy:'), 54),
#    (('hashtag', ':face_with_tears_of_joy:'), 54),
#    (('message', ':face_with_tears_of_joy:'), 53),
#    (('surprise', ':face_with_tears_of_joy:'), 53),
#    (('ha', ':face_with_tears_of_joy:'), 53),
#    (('bts', ':face_with_tears_of_joy:'), 53),
#    (('death', ':face_with_tears_of_joy:'), 53),
#    (('crocs', ':face_with_tears_of_joy:'), 53),
#    (('masterpiece', ':face_with_tears_of_joy:'), 53),
#    (('cannot', ':face_with_tears_of_joy:'), 53),
#    (('hype', ':face_with_tears_of_joy:'), 53),
#    (('remember', ':face_with_tears_of_joy:'), 53),
#    (('hungry', ':face_with_tears_of_joy:'), 53),
#    (('snow', ':face_with_tears_of_joy:'), 53),
#    (('girlfriends', ':face_with_tears_of_joy:'), 53),
#    (('future', ':face_with_tears_of_joy:'), 53),
#    (('heard', ':face_with_tears_of_joy:'), 53),
#    (('listen', ':face_with_tears_of_joy:'), 53),
#    (('who', ':face_with_tears_of_joy:'), 53),
#    (('jacket', ':face_with_tears_of_joy:'), 53),
#    (('cares', ':face_with_tears_of_joy:'), 53),
#    (('screamed', ':face_with_tears_of_joy:'), 53),
#    (('idiot', ':face_with_tears_of_joy:'), 52),
#    (('mins', ':face_with_tears_of_joy:'), 52),
#    (('little', ':face_with_tears_of_joy:'), 52),
#    (('t', ':face_with_tears_of_joy:'), 52),
#    (('sehun', ':face_with_tears_of_joy:'), 52),
#    (('through', ':face_with_tears_of_joy:'), 52),
#    (('effects', ':face_with_tears_of_joy:'), 52),
#    (('nah', ':face_with_tears_of_joy:'), 52),
#    (('book', ':face_with_tears_of_joy:'), 52),
#    (('call', ':face_with_tears_of_joy:'), 52),
#    (('drive', ':face_with_tears_of_joy:'), 52),
#    (('small', ':face_with_tears_of_joy:'), 52),
#    (('second', ':face_with_tears_of_joy:'), 52),
#    (('oh', ':face_with_tears_of_joy:'), 52),
#    (('retweet', ':face_with_tears_of_joy:'), 52),
#    (('texas', ':face_with_tears_of_joy:'), 52),
#    (('favorite', ':face_with_tears_of_joy:'), 51),
#    (('agree', ':face_with_tears_of_joy:'), 51),
#    (('commercial', ':face_with_tears_of_joy:'), 51),
#    (('film', ':face_with_tears_of_joy:'), 51),
#    (('candy', ':face_with_tears_of_joy:'), 51),
#    (('impression', ':face_with_tears_of_joy:'), 51),
#    (('kidding', ':face_with_tears_of_joy:'), 51),
#    (('fries', ':face_with_tears_of_joy:'), 51),
#    (('summer', ':face_with_tears_of_joy:'), 51),
#    (('changed', ':face_with_tears_of_joy:'), 50),
#    (('always', ':face_with_tears_of_joy:'), 50),
#    (('deadline', ':face_with_tears_of_joy:'), 50),
#    (('normal', ':face_with_tears_of_joy:'), 50),
#    (('wildin', ':face_with_tears_of_joy:'), 50),
#    (('bench', ':face_with_tears_of_joy:'), 50),
#    (('mode', ':face_with_tears_of_joy:'), 50),
#    (('scranton', ':face_with_tears_of_joy:'), 50),
#    (('neck', ':face_with_tears_of_joy:'), 50),
#    (('trips', ':face_with_tears_of_joy:'), 50),
#    (('straight', ':face_with_tears_of_joy:'), 50),
#    (('parents', ':face_with_tears_of_joy:'), 50),
#    (('incredible', ':face_with_tears_of_joy:'), 50),
#    (('entertaining', ':face_with_tears_of_joy:'), 50),
#    (('boo', ':face_with_tears_of_joy:'), 49),
#    (('legs', ':face_with_tears_of_joy:'), 49),
#    (('nervous', ':face_with_tears_of_joy:'), 49),
#    (('strong', ':face_with_tears_of_joy:'), 49),
#    (('goat', ':face_with_tears_of_joy:'), 49),
#    (('armys', ':face_with_tears_of_joy:'), 49),
#    (('cup', ':face_with_tears_of_joy:'), 49),
#    (('twitch', ':face_with_tears_of_joy:'), 49),
#    (('function', ':face_with_tears_of_joy:'), 49),
#    (('loool', ':face_with_tears_of_joy:'), 49),
#    (('fucked', ':face_with_tears_of_joy:'), 48),
#    (('charged', ':face_with_tears_of_joy:'), 48),
#    (('female', ':face_with_tears_of_joy:'), 48),
#    (('park', ':face_with_tears_of_joy:'), 48),
#    (('dms', ':face_with_tears_of_joy:'), 48),
#    (('public', ':face_with_tears_of_joy:'), 48),
#    (('medicine', ':face_with_tears_of_joy:'), 48),
#    (('ice', ':face_with_tears_of_joy:'), 48),
#    (('check', ':face_with_tears_of_joy:'), 48),
#    (('situation', ':face_with_tears_of_joy:'), 48),
#    (('raisins', ':face_with_tears_of_joy:'), 48),
#    (('stories', ':face_with_tears_of_joy:'), 48),
#    (('motion', ':face_with_tears_of_joy:'), 48),
#    (('petty', ':face_with_tears_of_joy:'), 48),
#    (('king', ':face_with_tears_of_joy:'), 48),
#    (('spot', ':face_with_tears_of_joy:'), 47),
#    (('teacher', ':face_with_tears_of_joy:'), 47),
#    (('yoongi', ':face_with_tears_of_joy:'), 47),
#    (('ridiculous', ':face_with_tears_of_joy:'), 47),
#    (('thru', ':face_with_tears_of_joy:'), 47),
#    (('field', ':face_with_tears_of_joy:'), 47),
#    (('forget', ':face_with_tears_of_joy:'), 47),
#    (('themselves', ':face_with_tears_of_joy:'), 47),
#    (('text', ':face_with_tears_of_joy:'), 47),
#    (('lives', ':face_with_tears_of_joy:'), 47),
#    (('count', ':face_with_tears_of_joy:'), 47),
#    (('asl', ':face_with_tears_of_joy:'), 47),
#    (('pony', ':face_with_tears_of_joy:'), 47),
#    (('finger', ':face_with_tears_of_joy:'), 47),
#    (('miami', ':face_with_tears_of_joy:'), 47),
#    (('scary', ':face_with_tears_of_joy:'), 47),
#    (('still', ':face_with_tears_of_joy:'), 47),
#    (('moments', ':face_with_tears_of_joy:'), 47),
#    (('anywhere', ':face_with_tears_of_joy:'), 47),
#    (('last', ':face_with_tears_of_joy:'), 47),
#    (('bye', ':face_with_tears_of_joy:'), 46),
#    (('pose', ':face_with_tears_of_joy:'), 46),
#    (('bus', ':face_with_tears_of_joy:'), 46),
#    (('baaad', ':face_with_tears_of_joy:'), 46),
#    (('fault', ':face_with_tears_of_joy:'), 46),
#    (('character', ':face_with_tears_of_joy:'), 46),
#    (('ponytail', ':face_with_tears_of_joy:'), 46),
#    (('eating', ':face_with_tears_of_joy:'), 46),
#    (('tongue', ':face_with_tears_of_joy:'), 46),
#    (('jump', ':face_with_tears_of_joy:'), 46),
#    (('plan', ':face_with_tears_of_joy:'), 45),
#    (('groceries', ':face_with_tears_of_joy:'), 45),
#    (('tattoo', ':face_with_tears_of_joy:'), 45),
#    (('clothes', ':face_with_tears_of_joy:'), 45),
#    (('exist', ':face_with_tears_of_joy:'), 45),
#    (('feet', ':face_with_tears_of_joy:'), 45),
#    (('interesting', ':face_with_tears_of_joy:'), 45),
#    (('champ', ':face_with_tears_of_joy:'), 45),
#    (('coach', ':face_with_tears_of_joy:'), 45),
#    (('pass', ':face_with_tears_of_joy:'), 45),
#    (('hampm', ':face_with_tears_of_joy:'), 45),
#    (('cut', ':face_with_tears_of_joy:'), 45),
#    (('chanyeol', ':face_with_tears_of_joy:'), 45),
#    (('ah', ':face_with_tears_of_joy:'), 45),
#    (('struggle', ':face_with_tears_of_joy:'), 45),
#    (('fortinite', ':face_with_tears_of_joy:'), 45),
#    (('street', ':face_with_tears_of_joy:'), 45),
#    (('pack', ':face_with_tears_of_joy:'), 45),
#    (('funniest', ':face_with_tears_of_joy:'), 45),
#    (('shame', ':face_with_tears_of_joy:'), 45),
#    (('feels', ':face_with_tears_of_joy:'), 44),
#    (('pants', ':face_with_tears_of_joy:'), 44),
#    (('nerves', ':face_with_tears_of_joy:'), 44),
#    (('sl', ':face_with_tears_of_joy:'), 44),
#    (('wall', ':face_with_tears_of_joy:'), 44),
#    (('titty', ':face_with_tears_of_joy:'), 44),
#    (('mistake', ':face_with_tears_of_joy:'), 44),
#    (('bout', ':face_with_tears_of_joy:'), 44),
#    (('his', ':face_with_tears_of_joy:'), 44),
#    (('hoop', ':face_with_tears_of_joy:'), 44),
#    (('hood', ':face_with_tears_of_joy:'), 44),
#    (('hey', ':face_with_tears_of_joy:'), 44),
#    (('famous', ':face_with_tears_of_joy:'), 44),
#    (('experience', ':face_with_tears_of_joy:'), 44),
#    (('d', ':face_with_tears_of_joy:'), 44),
#    (('trick', ':face_with_tears_of_joy:'), 44),
#    (('surprised', ':face_with_tears_of_joy:'), 44),
#    (('never', ':face_with_tears_of_joy:'), 43),
#    (('nigeria', ':face_with_tears_of_joy:'), 43),
#    (('blocked', ':face_with_tears_of_joy:'), 43),
#    (('members', ':face_with_tears_of_joy:'), 43),
#    (('looking', ':face_with_tears_of_joy:'), 43),
#    (('attack', ':face_with_tears_of_joy:'), 43),
#    (('didnt', ':face_with_tears_of_joy:'), 43),
#    (('manager', ':face_with_tears_of_joy:'), 43),
#    (('asap', ':face_with_tears_of_joy:'), 43),
#    (('conversation', ':face_with_tears_of_joy:'), 43),
#    (('nightstand', ':face_with_tears_of_joy:'), 43),
#    (('fits', ':face_with_tears_of_joy:'), 43),
#    (('join', ':face_with_tears_of_joy:'), 42),
#    (('how', ':face_with_tears_of_joy:'), 42),
#    (('moving', ':face_with_tears_of_joy:'), 42),
#    (('series', ':face_with_tears_of_joy:'), 42),
#    (('safe', ':face_with_tears_of_joy:'), 42),
#    (('lady', ':face_with_tears_of_joy:'), 42),
#    (('ws', ':face_with_tears_of_joy:'), 42),
#    (('unbelievable', ':face_with_tears_of_joy:'), 42),
#    (('united', ':face_with_tears_of_joy:'), 42),
#    (('purpose', ':face_with_tears_of_joy:'), 42),
#    (('awkward', ':face_with_tears_of_joy:'), 42),
#    (('btw', ':face_with_tears_of_joy:'), 42),
#    (('lock', ':face_with_tears_of_joy:'), 42),
#    (('dream', ':face_with_tears_of_joy:'), 42),
#    (('itchy', ':face_with_tears_of_joy:'), 42),
#    (('cigarette', ':face_with_tears_of_joy:'), 42),
#    (('adorable', ':face_with_tears_of_joy:'), 42),
#    (('matter', ':face_with_tears_of_joy:'), 42),
#    (('pizza', ':face_with_tears_of_joy:'), 42),
#    (('cheater', ':face_with_tears_of_joy:'), 42),
#    (('along', ':face_with_tears_of_joy:'), 42),
#    (('kyungsoo', ':face_with_tears_of_joy:'), 42),
#    (('mcdonalds', ':face_with_tears_of_joy:'), 42),
#    (('somewhere', ':face_with_tears_of_joy:'), 42),
#    (('duh', ':face_with_tears_of_joy:'), 42),
#    (('oo', ':face_with_tears_of_joy:'), 42),
#    (('reality', ':face_with_tears_of_joy:'), 42),
#    (('replies', ':face_with_tears_of_joy:'), 41),
#    (('pretty', ':face_with_tears_of_joy:'), 41),
#    (('screen', ':face_with_tears_of_joy:'), 41),
#    (('costs', ':face_with_tears_of_joy:'), 41),
#    (('spend', ':face_with_tears_of_joy:'), 41),
# ...
#    (('living', ':red_heart:'), 27),
#    (('joy', ':red_heart:'), 27),
#    (('cool', ':red_heart:'), 27),
#    (('or', ':red_heart:'), 27),
#    (('mandela', ':red_heart:'), 27),
#    (('account', ':red_heart:'), 27),
#    (('ㅠㅠ', ':red_heart:'), 27),
#    (('id', ':red_heart:'), 27),
#    (('bff', ':red_heart:'), 27),
#    (('girlfriend', ':red_heart:'), 27),
#    (('meet', ':red_heart:'), 27),
#    (('aww', ':red_heart:'), 27),
#    (('body', ':red_heart:'), 27),
#    (('creature', ':red_heart:'), 27),
#    (('london', ':red_heart:'), 27),
#    (('missed', ':red_heart:'), 27),
#    (('gtlt', ':red_heart:'), 27),
#    (('flattered', ':red_heart:'), 27),
#    (('favs', ':red_heart:'), 27),
#    (('urbanxdoll', ':red_heart:'), 27),
#    (('oppa', ':red_heart:'), 27),
#    (('stunning', ':red_heart:'), 27),
#    (('coconut', ':red_heart:'), 26),
#    (('grateful', ':red_heart:'), 26),
#    (('important', ':red_heart:'), 26),
#    (('book', ':red_heart:'), 26),
#    (('girly', ':red_heart:'), 26),
#    (('film', ':red_heart:'), 26),
#    (('heaven', ':red_heart:'), 26),
#    (('break', ':red_heart:'), 26),
#    (('em', ':red_heart:'), 26),
#    (('ig', ':red_heart:'), 26),
#    (('order', ':red_heart:'), 26),
#    (('new', ':red_heart:'), 26),
#    (('full', ':red_heart:'), 26),
#    (('set', ':red_heart:'), 26),
#    (('big', ':red_heart:'), 26),
#    (('comeback', ':red_heart:'), 26),
#    (('wedding', ':red_heart:'), 26),
#    (('khan', ':red_heart:'), 26),
#    (('im', ':red_heart:'), 26),
#    (('hello', ':red_heart:'), 25),
#    (('stream', ':red_heart:'), 25),
#    (('america', ':red_heart:'), 25),
#    (('easter', ':red_heart:'), 25),
#    (('play', ':red_heart:'), 25),
#    (('park', ':red_heart:'), 25),
#    (('crush', ':red_heart:'), 25),
#    (('ηα', ':red_heart:'), 25),
#    (('school', ':red_heart:'), 25),
#    (('youtube', ':red_heart:'), 25),
#    (('then', ':red_heart:'), 25),
#    (('magic', ':red_heart:'), 25),
#    (('old', ':red_heart:'), 25),
#    (('bank', ':red_heart:'), 25),
#    (('hands', ':red_heart:'), 25),
#    (('harry', ':red_heart:'), 25),
#    (('korea', ':red_heart:'), 24),
#    (('exams', ':red_heart:'), 24),
#    (('its', ':red_heart:'), 24),
#    (('magazine', ':red_heart:'), 24),
#    (('surprise', ':red_heart:'), 24),
#    (('loveee', ':red_heart:'), 24),
#    (('nyc', ':red_heart:'), 24),
#    (('comment', ':red_heart:'), 24),
#    (('color', ':red_heart:'), 24),
#    (('queens', ':red_heart:'), 24),
#    (('think', ':red_heart:'), 24),
#    (('sharing', ':red_heart:'), 24),
#    (('issue', ':red_heart:'), 24),
#    (('mum', ':red_heart:'), 24),
#    (('march', ':red_heart:'), 24),
#    (('laugh', ':red_heart:'), 24),
#    (('gain', ':red_heart:'), 24),
#    (('angels', ':red_heart:'), 24),
#    (('kindness', ':red_heart:'), 23),
#    (('doing', ':red_heart:'), 23),
#    (('listen', ':red_heart:'), 23),
#    (('tweets', ':red_heart:'), 23),
#    (('warm', ':red_heart:'), 23),
#    (('self', ':red_heart:'), 23),
#    (('page', ':red_heart:'), 23),
#    (('w', ':red_heart:'), 23),
#    (('agree', ':red_heart:'), 23),
#    (('swear', ':red_heart:'), 23),
#    (('ceremony', ':red_heart:'), 23),
#    (('yet', ':red_heart:'), 23),
#    (('alright', ':red_heart:'), 23),
#    (('c', ':red_heart:'), 23),
#    (('summer', ':red_heart:'), 23),
#    (('olympics', ':red_heart:'), 23),
#    (('stage', ':red_heart:'), 23),
#    (('links', ':red_heart:'), 23),
#    (('memory', ':red_heart:'), 23),
#    (('tap', ':red_heart:'), 23),
#    (('po', ':red_heart:'), 23),
#    (('menswear', ':red_heart:'), 23),
#    (('brothers', ':red_heart:'), 23),
#    (('bday', ':red_heart:'), 23),
#    (('player', ':red_heart:'), 23),
#    (('hat', ':red_heart:'), 23),
#    (('timeline', ':red_heart:'), 23),
#    (('healthy', ':red_heart:'), 23),
#    (('priceless', ':red_heart:'), 23),
#    (('winners', ':red_heart:'), 23),
#    (('matters', ':red_heart:'), 23),
#    (('ocean', ':red_heart:'), 23),
#    (('haters', ':red_heart:'), 23),
#    (('tears', ':red_heart:'), 22),
#    (('dawg', ':red_heart:'), 22),
#    (('appreciation', ':red_heart:'), 22),
#    (('top', ':red_heart:'), 22),
#    (('baileysusin', ':red_heart:'), 22),
#    (('start', ':red_heart:'), 22),
#    (('no', ':red_heart:'), 22),
#    (('anna', ':red_heart:'), 22),
#    (('others', ':red_heart:'), 22),
#    (('really', ':red_heart:'), 22),
#    (('kyiv', ':red_heart:'), 22),
#    (('messages', ':red_heart:'), 22),
#    (('months', ':red_heart:'), 22),
#    (('hours', ':red_heart:'), 22),
#    (('trying', ':red_heart:'), 22),
#    (('bed', ':red_heart:'), 22),
#    (('happening', ':red_heart:'), 22),
#    (('ones', ':red_heart:'), 22),
#    (('tv', ':red_heart:'), 22),
#    (('talented', ':red_heart:'), 22),
#    (('food', ':red_heart:'), 22),
#    (('screen', ':red_heart:'), 22),
#    (('still', ':red_heart:'), 22),
#    (('bundle', ':red_heart:'), 22),
#    (('lucky', ':red_heart:'), 22),
#    (('hobi', ':red_heart:'), 22),
#    (('mood', ':red_heart:'), 22),
#    (('light', ':red_heart:'), 22),
#    (('being', ':red_heart:'), 22),
#    (('moonbin', ':red_heart:'), 22),
#    (('maymay', ':red_heart:'), 22),
#    (('relationship', ':red_heart:'), 22),
#    (('via', ':red_heart:'), 22),
#    (('mark', ':red_heart:'), 21),
#    (('ate', ':red_heart:'), 21),
#    (('bunny', ':red_heart:'), 21),
#    (('hehe', ':red_heart:'), 21),
#    (('join', ':red_heart:'), 21),
#    (('brown', ':red_heart:'), 21),
#    (('arrived', ':red_heart:'), 21),
#    (('loss', ':red_heart:'), 21),
#    (('hashtag', ':red_heart:'), 21),
#    (('puppy', ':red_heart:'), 21),
#    (('y', ':red_heart:'), 21),
#    (('harder', ':red_heart:'), 21),
#    (('aegyo', ':red_heart:'), 21),
#    (('fave', ':red_heart:'), 21),
#    (('windbreakers', ':red_heart:'), 21),
#    (('fucking', ':red_heart:'), 21),
#    (('watching', ':red_heart:'), 21),
#    (('health', ':red_heart:'), 21),
#    (('dubai', ':red_heart:'), 21),
#    (('maine', ':red_heart:'), 21),
#    (('japan', ':red_heart:'), 21),
#    (('read', ':red_heart:'), 21),
#    (('dmwa', ':red_heart:'), 21),
#    (('group', ':red_heart:'), 21),
#    (('hey', ':red_heart:'), 21),
#    (('heartwarming', ':red_heart:'), 21),
#    (('football', ':red_heart:'), 21),
#    (('money', ':red_heart:'), 21),
#    (('message', ':red_heart:'), 21),
#    (('kid', ':red_heart:'), 21),
#    (('long', ':red_heart:'), 21),
#    (('sex', ':red_heart:'), 21),
#    (('chance', ':red_heart:'), 21),
#    (('tremendously', ':red_heart:'), 20),
#    (('jinjin', ':red_heart:'), 20),
#    (('thoughts', ':red_heart:'), 20),
#    (('article', ':red_heart:'), 20),
#    (('maknae', ':red_heart:'), 20),
#    (('v', ':red_heart:'), 20),
#    (('dms', ':red_heart:'), 20),
#    (('hyung', ':red_heart:'), 20),
#    (('waiting', ':red_heart:'), 20),
#    (('forgotten', ':red_heart:'), 20),
#    (('ahead', ':red_heart:'), 20),
#    (('reminder', ':red_heart:'), 20),
#    (('poshmark', ':red_heart:'), 20),
#    (('before', ':red_heart:'), 20),
#    (('needed', ':red_heart:'), 20),
#    (('jhope', ':red_heart:'), 20),
#    (('yoonsanha', ':red_heart:'), 20),
#    (('tt', ':red_heart:'), 20),
#    (('chat', ':red_heart:'), 20),
#    (('star', ':red_heart:'), 20),
#    (('mj', ':red_heart:'), 20),
#    (('trump', ':red_heart:'), 20),
#    (('christmas', ':red_heart:'), 20),
#    (('indeed', ':red_heart:'), 20),
#    (('below', ':red_heart:'), 20),
#    (('rider', ':red_heart:'), 19),
#    (('smiles', ':red_heart:'), 19),
#    (('version', ':red_heart:'), 19),
#    (('half', ':red_heart:'), 19),
#    (('jongin', ':red_heart:'), 19),
#    (('head', ':red_heart:'), 19),
#    (('itunes', ':red_heart:'), 19),
#    (('stars', ':red_heart:'), 19),
#    (('bomb', ':red_heart:'), 19),
#    (('was', ':red_heart:'), 19),
#    (('united', ':red_heart:'), 19),
#    (('lt', ':red_heart:'), 19),
#    (('white', ':red_heart:'), 19),
#    (('knowles', ':red_heart:'), 19),
#    (('faith', ':red_heart:'), 19),
#    (('pure', ':red_heart:'), 19),
#    (('plz', ':red_heart:'), 19),
#    (('boss', ':red_heart:'), 19),
#    (('jr', ':red_heart:'), 19),
#    (('afternoon', ':red_heart:'), 19),
#    (('gf', ':red_heart:'), 19),
#    (('minutes', ':red_heart:'), 19),
#    (('ahhh', ':red_heart:'), 19),
#    (('level', ':red_heart:'), 19),
#    (('but', ':red_heart:'), 19),
#    (('namjoon', ':red_heart:'), 19),
#    (('exciting', ':red_heart:'), 19),
#    (('phone', ':red_heart:'), 19),
#    (('click', ':red_heart:'), 19),
#    (('carpet', ':red_heart:'), 18),
#    (('pray', ':red_heart:'), 18),
#    (('goddess', ':red_heart:'), 18),
#    (('worth', ':red_heart:'), 18),
#    (('greater', ':red_heart:'), 18),
#    (('tight', ':red_heart:'), 18),
#    (('follows', ':red_heart:'), 18),
#    (('pakistan', ':red_heart:'), 18),
#    (('cast', ':red_heart:'), 18),
#    (('dogs', ':red_heart:'), 18),
#    (('anytime', ':red_heart:'), 18),
#    (('fuck', ':red_heart:'), 18),
#    (('vines', ':red_heart:'), 18),
#    (('match', ':red_heart:'), 18),
#    (('thankful', ':red_heart:'), 18),
#    (('history', ':red_heart:'), 18),
#    (('bestie', ':red_heart:'), 18),
#    (('ms', ':red_heart:'), 18),
#    (('lit', ':red_heart:'), 18),
#    (('nominations', ':red_heart:'), 18),
#    (('kiss', ':red_heart:'), 18),
#    (('wins', ':red_heart:'), 18),
#    (('slaughter', ':red_heart:'), 18),
#    (('journey', ':red_heart:'), 18),
#    (('weeks', ':red_heart:'), 18),
#    (('vibes', ':red_heart:'), 18),
#    (('snapchat', ':red_heart:'), 18),
#    (('solid', ':red_heart:'), 18),
#    (('homie', ':red_heart:'), 18),
#    (('cry', ':red_heart:'), 18),
#    (('junmyeon', ':red_heart:'), 18),
#    (('energy', ':red_heart:'), 18),
#    (('hq', ':red_heart:'), 18),
#    (('florida', ':red_heart:'), 18),
#    (('romance', ':red_heart:'), 18),
#    (('repost', ':red_heart:'), 18),
#    (('cut', ':red_heart:'), 18),
#    (('notifications', ':red_heart:'), 18),
#    (('dinner', ':red_heart:'), 17),
#    (('hai', ':red_heart:'), 17),
#    (('loving', ':red_heart:'), 17),
#    (('car', ':red_heart:'), 17),
#    (('amores', ':red_heart:'), 17),
#    (('crying', ':red_heart:'), 17),
#    (('rain', ':red_heart:'), 17),
#    (('mashallah', ':red_heart:'), 17),
#    (('vegas', ':red_heart:'), 17),
#    (('yokohama', ':red_heart:'), 17),
#    (('bhai', ':red_heart:'), 17),
#    (('insta', ':red_heart:'), 17),
#    (('hashtags', ':red_heart:'), 17),
#    (('stop', ':red_heart:'), 17),
#    (('tbh', ':red_heart:'), 17),
#    (('once', ':red_heart:'), 17),
#    (('chart', ':red_heart:'), 17),
#    (('members', ':red_heart:'), 17),
#    (('sky', ':red_heart:'), 17),
#    (('concept', ':red_heart:'), 17),
#    (('spot', ':red_heart:'), 17),
#    (('bad', ':red_heart:'), 17),
#    (('rebellion', ':red_heart:'), 17),
#    (('sign', ':red_heart:'), 17),
#    (('truth', ':red_heart:'), 17),
#    (('listening', ':red_heart:'), 17),
#    (('baaack', ':red_heart:'), 17),
#    (('husband', ':red_heart:'), 17),
#    (('dress', ':red_heart:'), 17),
#    (('souls', ':red_heart:'), 17),
#    (('along', ':red_heart:'), 17),
#    (('idea', ':red_heart:'), 17),
#    (('sure', ':red_heart:'), 17),
#    (('also', ':red_heart:'), 17),
#    (('stock', ':red_heart:'), 17),
#    (('anti', ':red_heart:'), 17),
#    (('students', ':red_heart:'), 17),
#    (('stuff', ':red_heart:'), 17),
#    (('interview', ':red_heart:'), 17),
#    (('finally', ':red_heart:'), 17),
#    (('said', ':red_heart:'), 17),
#    (('tata', ':red_heart:'), 17),
#    (('child', ':red_heart:'), 17),
#    (('hahaha', ':red_heart:'), 17),
#    (('pie', ':red_heart:'), 17),
#    (('redcarpet', ':red_heart:'), 16),
#    (('smiling', ':red_heart:'), 16),
#    (('mins', ':red_heart:'), 16),
#    (('ty', ':red_heart:'), 16),
#    (('ways', ':red_heart:'), 16),
#    (('ly', ':red_heart:'), 16),
#    (('million', ':red_heart:'), 16),
#    (('kyungsoo', ':red_heart:'), 16),
#    (('duke', ':red_heart:'), 16),
#    (('oht', ':red_heart:'), 16),
#    (('details', ':red_heart:'), 16),
#    (('lifetime', ':red_heart:'), 16),
#    (('niall', ':red_heart:'), 16),
#    (('yay', ':red_heart:'), 16),
#    (('squad', ':red_heart:'), 16),
#    (('series', ':red_heart:'), 16),
#    (('testino', ':red_heart:'), 16),
#    (('mg', ':red_heart:'), 16),
#    (('positivity', ':red_heart:'), 16),
#    (('inspiring', ':red_heart:'), 16),
#    (('shape', ':red_heart:'), 16),
#    (('april', ':red_heart:'), 16),
#    (('scenes', ':red_heart:'), 16),
#    (('dawn', ':red_heart:'), 16),
#    (('radio', ':red_heart:'), 16),
#    (('artist', ':red_heart:'), 16),
#    (('plan', ':red_heart:'), 16),
#    (('italy', ':red_heart:'), 16),
#    (('deep', ':red_heart:'), 16),
#    (('soft', ':red_heart:'), 16),
#    (('rest', ':red_heart:'), 16),
#    (('many', ':red_heart:'), 16),
#    (('luvvly', ':red_heart:'), 16),
#    (('gal', ':red_heart:'), 16),
#    (('breakdown', ':red_heart:'), 16),
#    (('voted', ':red_heart:'), 16),
#    (('bag', ':red_heart:'), 16),
#    (('nigga', ':red_heart:'), 16),
#    (('ship', ':red_heart:'), 16),
#    (('salamat', ':red_heart:'), 16),
#    (('strength', ':red_heart:'), 16),
#    (('fly', ':red_heart:'), 16),
#    (('planet', ':red_heart:'), 15),
#    (('ilovelies', ':red_heart:'), 15),
#    (('hate', ':red_heart:'), 15),
#    (('someday', ':red_heart:'), 15),
#    (('met', ':red_heart:'), 15),
#    (('caption', ':red_heart:'), 15),
#    (('something', ':red_heart:'), 15),
#    (('flies', ':red_heart:'), 15),
#    (('fish', ':red_heart:'), 15),
#    (('number', ':red_heart:'), 15),
#    (('birds', ':red_heart:'), 15),
#    (('shilpa', ':red_heart:'), 15),
#    (('families', ':red_heart:'), 15),
#    (('dates', ':red_heart:'), 15),
#    (('retweets', ':red_heart:'), 15),
#    (('ball', ':red_heart:'), 15),
#    (('legends', ':red_heart:'), 15),
#    (('scenario', ':red_heart:'), 15),
#    (('looove', ':red_heart:'), 15),
#    (('nadine', ':red_heart:'), 15),
#    (('bird', ':red_heart:'), 15),
#    (('xoxo', ':red_heart:'), 15),
#    (('unnie', ':red_heart:'), 15),
#    (('happier', ':red_heart:'), 15),
#    (('february', ':red_heart:'), 15),
#    (('studio', ':red_heart:'), 15),
#    (('selena', ':red_heart:'), 15),
#    (('town', ':red_heart:'), 15),
#    (('hand', ':red_heart:'), 15),
#    (('na', ':red_heart:'), 15),
#    (('ji', ':red_heart:'), 15),
#    (('hoodie', ':red_heart:'), 15),
#    (('daily', ':red_heart:'), 15),
#    (('philippines', ':red_heart:'), 15),
#    (('skin', ':red_heart:'), 15),
#    (('thuuu', ':red_heart:'), 15),
#    (('happened', ':red_heart:'), 15),
#    (('high', ':red_heart:'), 15),
#    (('celebration', ':red_heart:'), 15),
#    (('men', ':red_heart:'), 15),
#    (('james', ':red_heart:'), 15),
#    (('sisters', ':red_heart:'), 15),
#    (('reunion', ':red_heart:'), 15),
#    (('pa', ':red_heart:'), 15),
#    (('irreplaceable', ':red_heart:'), 15),
#    (('father', ':red_heart:'), 15),
#    (('winning', ':red_heart:'), 15),
#    (('portfolio', ':red_heart:'), 15),
#    (('feet', ':red_heart:'), 15),
#    (('weather', ':red_heart:'), 15),
#    (('anyway', ':red_heart:'), 14),
#    (('diamond', ':red_heart:'), 14),
#    (('messi', ':red_heart:'), 14),
#    (('colors', ':red_heart:'), 14),
#    (('playlists', ':red_heart:'), 14),
#    (('zayn', ':red_heart:'), 14),
#    (('whole', ':red_heart:'), 14),
#    (('legendinho', ':red_heart:'), 14),
#    (('trophy', ':red_heart:'), 14),
#    (('st', ':red_heart:'), 14),
#    (('brave', ':red_heart:'), 14),
#    (('dont', ':red_heart:'), 14),
#    (('babygirl', ':red_heart:'), 14),
#    (('internet', ':red_heart:'), 14),
#    (('feels', ':red_heart:'), 14),
#    (('perfection', ':red_heart:'), 14),
#    (('powerful', ':red_heart:'), 14),
#    (('se', ':red_heart:'), 14),
#    (('unforgettable', ':red_heart:'), 14),
#    (('keeper', ':red_heart:'), 14),
#    (('오빠', ':red_heart:'), 14),
#    (('chan', ':red_heart:'), 14),
#    (('singapore', ':red_heart:'), 14),
#    (('sade', ':red_heart:'), 14),
#    (('cosmetics', ':red_heart:'), 14),
#    (('compassionate', ':red_heart:'), 14),
#    (('belle', ':red_heart:'), 14),
#    (('fabulous', ':red_heart:'), 14),
#    (('impact', ':red_heart:'), 14),
#    (('deal', ':red_heart:'), 14),
#    (('pack', ':red_heart:'), 14),
#    (('camera', ':red_heart:'), 14),
#    (('yixing', ':red_heart:'), 14),
#    (('app', ':red_heart:'), 14),
#    (('moreee', ':red_heart:'), 14),
#    (('chaeunwoo', ':red_heart:'), 14),
#    (('miracle', ':red_heart:'), 14),
#    (('church', ':red_heart:'), 14),
#    (('get', ':red_heart:'), 14),
#    (('grandpa', ':red_heart:'), 14),
#    (('jam', ':red_heart:'), 14),
#    (('shop', ':red_heart:'), 14),
#    (('class', ':red_heart:'), 14),
#    (('vcr', ':red_heart:'), 14),
#    (('feature', ':red_heart:'), 14),
#    (('amor', ':red_heart:'), 14),
#    (('legs', ':red_heart:'), 14),
#    ...])]

# %%
result_df = result_2.toDF()

# %%
result_df.write.format("com.mongodb.spark.sql.DefaultSource").mode("append").save()
